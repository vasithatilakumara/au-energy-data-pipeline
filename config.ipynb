# %%
# Set environment variable
ENV = "dev"

# Define catalog and schema prefix for table names
CATALOG = f"energyau2026"
SCHEMA_PREFIX = f"energyau_{ENV}"

# Define fully qualified table names for different layers and purposes
BRONZE_TABLE = f"{CATALOG}.{SCHEMA_PREFIX}_bronze.price_and_demand"
SILVER_TABLE = f"{CATALOG}.{SCHEMA_PREFIX}_silver.price_and_demand"
REJECT_TABLE = f"{CATALOG}.{SCHEMA_PREFIX}_silver.price_and_demand_rejects"
GOLD_DEMAND_TABLE = f"{CATALOG}.{SCHEMA_PREFIX}_gold.hourly_demand_trends"
GOLD_SPIKE_TABLE = f"{CATALOG}.{SCHEMA_PREFIX}_gold.price_spikes"
GOLD_STRESS_TABLE = f"{CATALOG}.{SCHEMA_PREFIX}_gold.grid_stress_periods"
GOLD_BATTERY_DISPATCH_TABLE = f"{CATALOG}.{SCHEMA_PREFIX}_gold.battery_dispatch_signals"

# %%
# =====================================
# INIT: Ensure catalog & schemas exist
# =====================================

spark.sql(f"""
CREATE SCHEMA IF NOT EXISTS {CATALOG}.{SCHEMA_PREFIX}_bronze
""")

spark.sql(f"""
CREATE SCHEMA IF NOT EXISTS {CATALOG}.{SCHEMA_PREFIX}_silver
""")

spark.sql(f"""
CREATE SCHEMA IF NOT EXISTS {CATALOG}.{SCHEMA_PREFIX}_gold
""")

spark.sql(f"""
CREATE SCHEMA IF NOT EXISTS {CATALOG}.{SCHEMA_PREFIX}_silver_rejects
""")
