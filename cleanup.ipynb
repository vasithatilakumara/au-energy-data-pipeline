# %% [markdown]
# # Databricks Space cleanup
# Azure and databricks space resource clean up to stop cost accumulation

# %% [markdown]
# ## Delete Catalogs

# %%
# %sql
-- This removes:
-- schemas
-- tables (bronze/silver/gold)
DROP CATALOG energyau_dev CASCADE;

# %% [markdown]
# ## Delete External Location
#
# Go to: Catalog -> External Locations
# Delete: energy_landin_locations

# %% [markdown]
# ## Delete Storage Credential
# Go to: Catalog -> Credentials
# Delete: energyau_storage_cred

# %% [markdown]
# ## Clean ADLS storage
#
# Delete folders:
# - landing/
# - checkpoints/
# - schemas/
